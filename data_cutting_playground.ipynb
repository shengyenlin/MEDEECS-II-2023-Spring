# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-ryehwge5 because the default path (/home/guest/r11922a05/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# ## Image box
# - Upper image: (xmin, xmax, ymin, ymax) = (445, 1540, 75, 490)
# - Lower image: (xmin, xmax, ymin, ymax) = (445, 1540, 523, 938)

# %%
image = mpimg.imread('data/P215350000005/P215350000005_20170110_OCT_OD_1.jpg')

# %%
plt.imshow(image)
y = 75; plt.axhline(y, color='r', linewidth=0.5)
x = 445; plt.axvline(x, color='b', linewidth=0.5)
y = 490; plt.axhline(y, color='r', linewidth=0.5)
x = 1540; plt.axvline(x, color='b', linewidth=0.5)
plt.show()

# %%
plt.imshow(image)
y = 523; plt.axhline(y, color='r', linewidth=0.5)
x = 445; plt.axvline(x, color='b', linewidth=0.5)
y = 938; plt.axhline(y, color='r', linewidth=0.5)
x = 1540; plt.axvline(x, color='b', linewidth=0.5)
plt.show()
